# %%
import pandas as pd

# %% [markdown]
# ## pd.pivot(data, index=None, columns=None, values=None)
# ###    * 지정된 인덱스/열 값으로 구성된 재구성된 데이터 프레임을 반환한다.

# %% [markdown]
# ### Parameters : data : DataFrame
# ####           * index : str or object or a list of str, optional
# ####           * columns : str or object or a list of str
# ####           * values : str, object or a list of the previous, optional
#
# ### Returns : DataFrame
# ####            - Returns reshaped DataFrame
# ### Raises : ValueError :
# ####            - 인덱스가 있으면 열이 여러 값과 결합된다. 집계해야 하는 경우 DataFrame.pivot_table.

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar')['baz']
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar', values=['baz','zoo'])
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %% [markdown]
# ### * 열 이름 목록 또는 인덱스 이름 목록을 할당할 수 있다.

# %%
df = pd.DataFrame({
        'lev1': [1, 1, 1, 2, 2, 2],
        'lev2': [1, 1, 2, 1, 1, 2],
        'lev3': [1, 2, 1, 2, 1, 2],
        'lev4': [1, 2, 3, 4, 5, 6],
        'values': [0, 1, 2, 3, 4, 5]})
df
# Out:
#    lev1  lev2  lev3  lev4  values
# 0     1     1     1     1       0
# 1     1     1     2     2       1
# 2     1     2     1     3       2
# 3     2     1     2     4       3
# 4     2     1     1     5       4
# 5     2     2     2     6       5

# %%
df.pivot(index='lev1', columns=['lev2','lev3'], values='values')
# Out:
# lev2    1         2
# lev3    1    2    1    2
# lev1
# 1     0.0  1.0  2.0  NaN
# 2     4.0  3.0  NaN  5.0

# %%
df.pivot(index=['lev1','lev2'],columns=['lev3'], values='values')
# Out:
# lev3         1    2
# lev1 lev2
# 1    1     0.0  1.0
#      2     2.0  NaN
# 2    1     4.0  3.0
#      2     NaN  5.0

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'two','two'],
                   'bar': ['A', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4]})
df
# Out:
#    foo bar  baz
# 0  one   A    1
# 1  one   A    2
# 2  two   B    3
# 3  two   C    4

# %% [markdown]
# ### * 처음 두 행은 인덱스 및 열 인수에 대해 동일하다 (오류 항목)

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2f9eca6fee6a> in <module>
# ----> 1 df.pivot(index='foo', columns='bar', values='baz')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    6676         from pandas.core.reshape.pivot import pivot
#    6677
# -> 6678         return pivot(self, index=index, columns=columns, values=values)
#    6679
#    6680     _shared_docs[
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 477     return indexed.unstack(columns)
#     478
#     479
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
# ...
